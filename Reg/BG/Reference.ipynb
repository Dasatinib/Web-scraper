# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import os -> for file deletion

# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

import requests
import pprint
import pyperclip

# %%
html=urlopen("https://www.bda.bg/images/stories/documents/bdias/drugs2_list2_1.htm")
soup=BeautifulSoup(html)

# %%
link_list=[]

for link in soup.find_all("a",href=re.compile("http://www.bda.bg")):
    temp=link.get("href")
    link_list.append(temp)

#print(link_list) # -> NEED TO USE A DIFFERENT DECOMPOSE ON w AND MAYBE xyz AS WELL
# Out:
# http://www.bda.bg/images/stories/documents/bdias/A-1.htm
# http://www.bda.bg/images/stories/documents/bdias/B-1.htm
# http://www.bda.bg/images/stories/documents/bdias/C-1.htm
# http://www.bda.bg/images/stories/documents/bdias/D-1.htm
# http://www.bda.bg/images/stories/documents/bdias/E-1.htm
# http://www.bda.bg/images/stories/documents/bdias/F-1.htm
# http://www.bda.bg/images/stories/documents/bdias/G-1.htm
# http://www.bda.bg/images/stories/documents/bdias/H-1.htm
# http://www.bda.bg/images/stories/documents/bdias/I-1.htm
# http://www.bda.bg/images/stories/documents/bdias/J-1.htm
# http://www.bda.bg/images/stories/documents/bdias/K-1.htm
# http://www.bda.bg/images/stories/documents/bdias/L-1.htm
# http://www.bda.bg/images/stories/documents/bdias/M-1.htm
# http://www.bda.bg/images/stories/documents/bdias/N-1.htm
# http://www.bda.bg/images/stories/documents/bdias/O-1.htm
# http://www.bda.bg/images/stories/documents/bdias/P-1.htm
# ...

# %%
open("output1.html","w+")
# Out:
# <_io.TextIOWrapper name='output1.html' mode='w+' encoding='cp1252'>

# %%
urls = link_list
#scrape elements
for url in urls:
    response = requests.get(url)
    soup1 = BeautifulSoup(response.content)
    with open("output1.html", "a+", encoding='utf-8') as file:
        file.write(str(soup1))

# %%
#Openning output

f = open("output1.html", encoding='UTF-8')
soup = BeautifulSoup(f, 'html.parser')

# %%
# table = soup.findAll('table')[0]
# rows = table.findAll('tr')

# first_columns = []
# third_columns = []
# for row in rows:
#     first_columns.append(row.findAll('td')[0].contents)

# %%
# with open("output2.html", "a+", encoding='utf-8') as file:
#          file.write(str(soup))

# %%
# unwanted = soup.find_all(class_=["xl24", "xl71"])
# for span in unwanted:
#     span.decompose()

# %%
# with open("output2.html", "a+", encoding='utf-8') as file:
#         file.write(str(soup))

# %%
rowsa = soup.select('table tr td:nth-of-type(1)')
rowsb = soup.select('table tr td:nth-of-type(2)')

A = []
B = []

for row in rowsa:
    A.append(row.text)
for row in rowsb:
    B.append(row.text)

A = pd.Series(A, name="Product")
A = A.str.replace("\r", "")
A = A.str.replace("\n", "")
A = A.str.replace("\xa0", "")
A.replace('', np.nan, inplace=True)
first_idx = A.first_valid_index()
last_idx = A.last_valid_index()
A = A.loc[first_idx:last_idx]
#A.dropna(inplace=True)
#A.reset_index(drop=True)

B = pd.Series(B, name="Strength")
B = B.str.replace("\r", "")
B = B.str.replace("\n", "")
B = B.str.replace("\xa0", "")
B.replace('', np.nan, inplace=True)
first_idx = B.first_valid_index()
last_idx = B.last_valid_index()
B = B.loc[first_idx:last_idx]
#B.dropna(inplace=True)
#B.reset_index(drop=True)

# %%
X = pd.concat([A.reset_index(drop=True), B.reset_index(drop=True)], axis=1)

# %%
#Printing out a single page to a file

X.to_csv("FINAL1.csv", index=False)
