# %%
import pandas as pd
import numpy as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
url="http://www.sukl.cz/modules/medication/search.php?data%5Bsearch_for%5D=&data%5Bcode%5D=&data%5Batc_group%5D=&data%5Bmaterial%5D=&data%5Bpath%5D=&data%5Breg%5D=&data%5Bradio%5D=none&data%5Brc%5D=&data%5Bchbox%5D%5B%5D=braill-yes&data%5Bchbox%5D%5B%5D=braill-no&data%5Bchbox%5D%5B%5D=braill-def&data%5Bwith_adv%5D=0&search=Vyhledat&data%5Blisting%5D=20"
html=urlopen(url)
soup=BeautifulSoup(html, "lxml")

# %%
for link in soup.find_all("a"):
    print(link.get("href"))
# Out:
# #main-content-center
# #menu
# http://www.sukl.cz/informacni-stredisko
# http://www.olecich.cz
# http://www.sukl.cz/komunikace-s-medii
# http://www.sukl.cz
# http://www.sukl.cz
# http://www.sukl.cz/leciva
# https://www.niszp.cz/
# http://www.sukl.cz/lekarny
# http://www.sukl.cz/zdravotnicka-zarizeni
# http://www.sukl.cz/farmaceuticky-prumysl
# http://www.sukl.cz/distribuce-1
# http://www.sukl.cz/sukl
# http://www.sukl.cz
# http://www.sukl.cz/file/69047/
# http://www.sukl.cz/modules/medication/atc_tree.php
# https://opendata.sukl.cz/?q=katalog/ochranne-prvky-seznamy-odchylek-dle-narizeni-komise-eu-c2016161
# http://www.sukl.cz/modules/medication/detail.php?kod=0207988
# http://www.sukl.cz/modules/medication/search.php?data%5Batc_group%5D=V09IX04&data%5Bwith_adv%5D=0
# http://www.sukl.cz/modules/medication/detail.php?kod=0250743
# http://www.sukl.cz/modules/medication/download.php?file=SPC162168.pdf&type=spc&as=18f-fdg-fr-spc
# ...

# %%
soup.a["title"]
# Out:
# 'Přejít na obsah [klávesová zkratka Alt+S]'

# %%
links=soup.find_all("a")

for link in links:
    print(link["title"])
    else("0")
# Out:
#   File "<ipython-input-49-ad476dbc4a22>", line 5
#     else("0")
#     ^
# SyntaxError: invalid syntax
