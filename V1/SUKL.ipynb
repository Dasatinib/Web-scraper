# %%
import pandas as pd
import numpy as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
url="http://www.sukl.cz/modules/medication/search.php?data%5Bsearch_for%5D=&data%5Bcode%5D=&data%5Batc_group%5D=&data%5Bmaterial%5D=&data%5Bpath%5D=&data%5Breg%5D=&data%5Bradio%5D=none&data%5Brc%5D=&data%5Bchbox%5D%5B%5D=braill-yes&data%5Bchbox%5D%5B%5D=braill-no&data%5Bchbox%5D%5B%5D=braill-def&data%5Bwith_adv%5D=0&search=Vyhledat&data%5Blisting%5D=100"
html=urlopen(url)
soup=BeautifulSoup(html, "lxml")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="cs" xml:lang="cs" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <script type="text/javascript">
#
#     var _gaq = _gaq || [];
#      _gaq.push(
#               ['_setAccount', 'UA-18406392-1'],
#             ['_setCustomVar', 2, 'Weekday', '6', 2],
#       ['_trackPageview']
#     );
#
#
#
#     (function() {
#       var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#       ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#       var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#     })();
#   </script>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="cs" http-equiv="content-language"/>
# <meta content="index,follow" name="robots"/>
# <meta content="databáze registrovaných léčiv, databáze lékáren, zdravotnická zařízení, distribuce léčiv" name="keywords"/>
# <meta content="SÚKL zajišťuje, aby v ČR byla dostupná pouze kvalitní, účinná a bezpečná humánní léčiva, a aby byly používány pouze bezpečné a funkční zdravotnické prostředky." name="description"/>
# <meta content="general" name="rating"/>
# <meta content="QCM s.r.o." name="author"/>
# <meta content="Copyright © 2001-2007" name="copyright"/>
# <meta content="Marwel" name="generator"/>
# <title>Státní ústav pro kontrolu léčiv</title>
# <link href="http://www.sukl.cz/favicon.ico" rel="SHORTCUT ICON"/>
# <link href="http://www.sukl.cz/themes/sukl2/css/main.css?202008310028" media="screen, projection" rel="stylesheet" type="text/css"/>
# <link href="http://www.sukl.cz/themes/sukl2/css/print.css?3012101136" media="print" rel="stylesheet" type="text/css"/>
# <link href="http://www.sukl.cz/themes/sukl2/css/handheld.css" media="handheld" rel="stylesheet" type="text/css"/>
# <link href="http://www.sukl.cz/themes/sukl2/css/inline.css" media="screen, projection" rel="stylesheet" type="text/css"/>
# <link href="http://www.sukl.cz/rss/cs" rel="alternate" title="RSS webu Státní ústav pro kontrolu léčiv" type="application/rss+xml"/>
# <script src="http://www.sukl.cz/themes/sukl2/js/AC_OETags.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/scriptaculous/lib/prototype.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/scriptaculous/scriptaculous.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/qcm/qcm.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/global.js?202008260824" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/flashcontrol/swfobject.js" type="text/javascript"></script>
# <script src="http://maps.google.com/maps/api/js?sensor=false&amp;region=cs" type="text/javascript"></script>
# <link href="http://www.sukl.cz/themes/sukl2/js/calendar/calendar-blue.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="http://www.sukl.cz/themes/sukl2/js/calendar/calendar.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/calendar/lang/calendar-cs.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/themes/sukl2/js/calendar/calendar-setup.js" type="text/javascript"></script>
# <link href="http://www.sukl.cz/modules/medication/css/medication.css" media="screen" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#     <!--
#     //--></script><script src="http://www.sukl.cz/modules/marwel/js/behavior.js" type="text/javascript"></script>
# <script src="http://www.sukl.cz/modules/marwel/js/dots.js" type="text/javascript"></script>
# <script type="text/javascript"><!--
#   Behaviour.addLoadEvent(function(){replaceDots();});
# --></script>
# <script type="text/javascript"><!--
#     //-->
#
#     Cookie.init({name: 'jscoockies'}, {});
#     </script>
# <script src="http://www.sukl.cz/themes/sukl2/js/suklIntranet.php" type="text/javascript"></script>
# <script type="text/javascript">
#       <!--
#         function addSUKLIntranetOnLoad() {
#           var oldonload = window.onload;
#
#           if (typeof window.onload != 'function') {
#             window.onload = function() {
#               showSUKLIntranet();
#             }
#           } else {
#             window.onload = function() {
#               oldonload();
#               showSUKLIntranet();
#             }
#           }
#         }
#
#         addSUKLIntranetOnLoad();
#       //-->
#     </script>
# <!--[if IE 6]>
# <link rel="stylesheet" href="http://www.sukl.cz/themes/sukl2/css/ie6.css"     type="text/css" media="screen, projection" />
# <![endif]-->
# </head>
# <body id="www-sukl-cz">
# <div id="warn-box-bg" style="display: none;"></div>
# <div id="warn-box" style="display: none;">
# <div class="warn-box-cnt">
# <div class="bcc" id="b-51">
# <h2>VSTUP DO BUDOV SÚKL POUZE S OCHRANOU DÝCHACÍCH CEST</h2>
# <div class="article-content">
# <p>
# Z důvodu prevence šíření nemoci COVID-19 jsou všichni povinni v budovách, ve kterých vykonávají svoji činnost orgány veřejné moci a správní orgány a které jsou určené pro kontakt s veřejností, a v době, kdy slouží pro tento účel, nosit ochranu dýchacích cest. Platí to i při vstupu do všech budov SÚKL a na všech našich pracovištích.
# </p>
# <p>
# Použijte vždy ochranu úst a nosu – roušku, respirátor, šátek, případně šálu. Pokud jdete na předem domluvenou schůzku, jednání, konzultaci apod., vybavte se prosím těmito ochrannými pomůckami. V opačném případě nebudete do budovy SÚKL vpuštěni.
# </p>
# <p>
# Žádáme veřejnost a všechny návštěvy o striktní dodržování stanovených pravidel.
# </p>
# <p>
# Děkujeme za pochopení.
# </p>
# </div>
# </div>
# <div class="cleaner"></div>
# <div id="warn-box-close">x</div>
# </div>
# </div>
# <script type="text/javascript">
#         document.observe("dom:loaded", function() {
#           showWarnBox();
#         });
#       </script>
# <div id="wrapper">
# <div id="all">
# <div id="header">
# <a accesskey="s" class="hidden-nav" href="#main-content-center" title="Přejít na obsah [klávesová zkratka Alt+S]">Skoč na obsah</a>
# <a accesskey="n" class="hidden-nav" href="#menu" title="Skoč na navigaci">Skoč na navigaci</a>
# <div class="column-in">
# <div id="personification">
# <div class="bl" id="b-6">
# <span class="left_menu_top"></span> <ul class="level1">
# <li class="first">
# <a class="informacni-stredisko" href="http://www.sukl.cz/informacni-stredisko" title="Informační středisko">Informační středisko</a>
# </li>
# <li class="e">
# <a class="verejnost" href="http://www.olecich.cz" title="Veřejnost">Veřejnost</a>
# </li>
# <li class="o">
# <a class="komunikace-s-medii" href="http://www.sukl.cz/komunikace-s-medii" title="Média">Média</a>
# </li>
# </ul>
# </div>
# </div>
# <h1 id="logo" title="Státní ústav pro kontrolu léčiv"><a href="http://www.sukl.cz"><span> </span>Státní ústav pro kontrolu léčiv</a></h1>
# <div id="row-site-navigation">
# <a class="home_btn" href="http://www.sukl.cz"><span> </span>Státní ústav pro kontrolu léčiv</a>
# <div class="bl" id="b-5">
# <span class="left_menu_top"></span> <ul class="level1">
# <li class="first">
# <a class="leciva" href="http://www.sukl.cz/leciva" title="Léčiva">Léčiva</a>
# </li>
# <li class="e">
# <a class="zdravotnicke-prostredky" href="https://www.niszp.cz/" title="Zdravotnické prostředky">Zdravotnické prostředky</a>
# </li>
# <li class="o">
# <a class="lekarny" href="http://www.sukl.cz/lekarny" title="Lékárny">Lékárny</a>
# </li>
# <li class="e">
# <a class="zdravotnicka-zarizeni" href="http://www.sukl.cz/zdravotnicka-zarizeni" title="Zdravotnická zařízení">Zdravotnická zařízení</a>
# </li>
# <li class="o">
# <a class="farmaceuticky-prumysl" href="http://www.sukl.cz/farmaceuticky-prumysl" title="Farmaceutický průmysl">Farmaceutický průmysl</a>
# </li>
# <li class="e">
# <a class="distribuce-1" href="http://www.sukl.cz/distribuce-1" title="Distribuce">Distribuce</a>
# </li>
# <li class="o">
# <a class="sukl" href="http://www.sukl.cz/sukl" title="SÚKL">SÚKL</a>
# </li>
# </ul>
# </div>
# <div class="cleaner"> </div>
# </div>
# </div>
# </div>
# <div id="main">
# <div class="innerwrap">
# <div class="middle">
# <div class="column-in" id="content">
# <div id="main-content-center">
# <div class="breadcrumb">
# <a href="http://www.sukl.cz" title="Zobrazit titulní stránku">Úvod</a>
# /
# <span title="Aktuální článek:"><em>Databáze léků</em></span>
# </div>
# <div class="blockContent">
# <div class="medication">
# <form action="http://www.sukl.cz/modules/medication/search.php" method="get">
# <fieldset>
# <h3>Vyhledávání</h3>
# <div class="medication_search_manual"><a href="http://www.sukl.cz/file/69047/">Návod k vyhledávání</a></div>
# <div class="block-texts">
# <label for="data_search_for">Začátek názvu léčivého přípravku:</label>
# <input id="data_search_for" name="data[search_for]" type="text" value=""/>
# <label for="data_code">Kód SÚKL:</label>
# <input id="data_code" name="data[code]" type="text" value=""/>
# <label for="data_atc"><a href="http://www.sukl.cz/modules/medication/atc_tree.php" onclick="window.open(this.href); return false;" title="Anatomicko-terapeutická skupina - přehled se otevře v novém okně">ATC skupina</a>:</label>
# <input id="data_atc" name="data[atc_group]" type="text" value=""/>
# <label for="data_material">Začátek názvu účinné látky:</label>
# <input id="data_material" name="data[material]" type="text" value=""/>
# <label for="data_path">Cesta podání:</label>
# <select id="data_path" name="data[path]" size="1">
# <option value=""> - nerozhoduje - </option>
# <option value="AUR">
# Ušní podání            </option>
# <option value="AUR/OPH">
# Ušní/oční podání            </option>
# <option value="BUC">
# Bukální podání            </option>
# <option value="BUC/IMS/IVN/NAS">
# Bukální/intramuskulární/intravenózní/nosní podání            </option>
# <option value="DNT">
# Dentální podání            </option>
# <option value="DRM">
# Kožní podání            </option>
# <option value="DRM/INH">
# Kožní/inhalační podání            </option>
# <option value="EAC">
# Mimotělní podání            </option>
# <option value="EPD/IAT/IFL">
# Epidurální/intraartikulární podání/infiltrace            </option>
# <option value="EPD/IAT/PNR/SDR">
# Epidurální/intraartikulární/perineurální/subkutánní podání            </option>
# <option value="EPD/IMS/IVN/SDR">
# Epidurální/intramuskulární/intravenózní/subkutánní            </option>
# <option value="EPD/ITH/IFL">
# Epidurální/intratekální/infiltrace            </option>
# <option value="EPD/ITH/PNR/IFL">
# Epidurální/intratekální/perineurální podání/infiltrace            </option>
# <option value="EPL">
# Epilezionální podání            </option>
# <option value="EPL/IMP">
# Epilezionální podání/implantace            </option>
# <option value="ETP">
# Endotracheopulmonální podání            </option>
# <option value="GST">
# Gastroenterální podání            </option>
# <option value="HMD">
# Hemodialýza            </option>
# <option value="HMD/IVN">
# Hemodialýza/intravenózní podání            </option>
# <option value="IAM">
# Intraamniotické podání            </option>
# <option value="IAM/IMS">
# Intraamniotické/intramuskulární podání            </option>
# <option value="IAR">
# Intraarteriální podání            </option>
# <option value="IAR/IAT/ICP/IVN">
# Intraarteriální/intraartikulární/intracholangiopankreatické//intravenózní podání            </option>
# <option value="IAR/ILF">
# Intraarteriální/intralymfatické podání            </option>
# <option value="IAR/IMS/ITH/IVN">
# Intraarteriální/intramuskulární/intratekální/intravenózní podání            </option>
# <option value="IAR/IMS/IVN">
# Intraarteriální/intramuskulární/intravenózní            </option>
# <option value="IAR/IPL/IPT/IVN">
# Intraarteriální/intrapleurální/intraperitoneální/intravenózní podání            </option>
# <option value="IAR/IVN">
# Intraarteriální/intravenózní podání            </option>
# <option value="IAR/IVN/ITH">
# Intraarteriální/intravenózní/intratekální podání            </option>
# <option value="IAT">
# Intraartikulární podání            </option>
# <option value="IAT/IBR/IMS/IVN">
# Intraartikulární/intraburzální/intramuskulární/intravenózní podání            </option>
# <option value="IAT/PAT">
# Intraartikulární/periartikulární podání            </option>
# <option value="ICC/IUT">
# Intracervikální/intrauterinní podání            </option>
# <option value="ICC/IVN">
# Intracervikální/intravenózní podání            </option>
# <option value="ICL">
# Intracerebroventrikulární podání            </option>
# <option value="ICM">
# Podání do přední oční komory            </option>
# <option value="ICN">
# Intrakoronární podání            </option>
# <option value="ICN/IVN">
# Intrakoronární/intravenózní podání            </option>
# <option value="ICT/IVN">
# Intracisternální/intravenózní  podání            </option>
# <option value="ICV">
# Intrakavernózní podání            </option>
# <option value="IDR">
# Intradermální podání            </option>
# <option value="IDR/IMS">
# Intradermální/intramuskulární podání            </option>
# <option value="IDR/IMS/SDR">
# Intradermální/intramuskulární/subkutánní podání            </option>
# <option value="IDR/SDR/ITM/PTM">
# Intradermální/subkutánní/intratumorózní/peritumorózní podání            </option>
# <option value="IFL">
# Infiltrace            </option>
# <option value="IFL/PNR">
# Infiltrace/perineurální podání            </option>
# <option value="IGD/IMS">
# Intraglandulární/intramuskulární podání            </option>
# <option value="ILS">
# Intralezionální podání            </option>
# <option value="IMP">
# Implantace            </option>
# <option value="IMS">
# Intramuskulární podání            </option>
# <option value="IMS/IVN">
# Intramuskulární/intravenózní podání            </option>
# <option value="IMS/IVN/IFL">
# Intramuskulární/intravenózní podání/infiltrace            </option>
# <option value="IMS/IVN/INH">
# Intramuskulární/intravenózní/inhalační podání            </option>
# <option value="IMS/IVN/IOS">
# Intramuskulární/intravenózní/intraoseální podání            </option>
# <option value="IMS/IVN/ITH">
# Intramuskulární/intravenózní/intratekální podání            </option>
# <option value="IMS/IVN/IUT/NAS">
# Intramuskulární/intravenózní/intrauterinní/nosní podání            </option>
# <option value="IMS/IVN/POR">
# Intramuskulární/intravenózní/perorální podání            </option>
# <option value="IMS/IVN/RCT">
# Intramuskulární/intravenózní/rektální podání            </option>
# <option value="IMS/IVN/SCI">
# Intramuskulární/intravenózní/subkonjunktivální podání            </option>
# <option value="IMS/IVN/SDR/IFL">
# Intramuskulární/intravenózní/subkutánní podání/infiltrace            </option>
# <option value="INH">
# Inhalační podání            </option>
# <option value="INH/IVN">
# Inhalační/intravenózní podání            </option>
# <option value="INH/IVN/POR">
# Inhalační/intravenózní/perorální podání            </option>
# <option value="INT">
# Intestinální podání            </option>
# <option value="IOC">
# Nitrooční podání            </option>
# <option value="IPT">
# Intraperitoneální podání            </option>
# <option value="ITH">
# Intratekální podání            </option>
# <option value="IUT">
# Intrauterinní podání            </option>
# <option value="IVI">
# Intravitreální podání            </option>
# <option value="IVN">
# Intravenózní podání            </option>
# <option value="IVN/EPD">
# Intravenózní/epidurální podání            </option>
# <option value="IVN/IVS">
# Intravenózní/intravezikální podání            </option>
# <option value="IVN/IVS/IAR">
# Intravenózní/intravezikální/intraarteriální podání            </option>
# <option value="IVN/OPH">
# Intravenózní/oční podání            </option>
# <option value="IVN/OPH/EAC">
# Intravenózní/oční/mimotělní podání            </option>
# <option value="IVN/POR">
# Intravenózní/perorální podání            </option>
# <option value="IVN/RCT">
# Intravenózní/rektální podání            </option>
# <option value="IVS">
# Intravezikální podání            </option>
# <option value="NAS">
# Nosní podání            </option>
# <option value="OPH">
# Oční podání            </option>
# <option value="OPH/NAS">
# Oční/nosní podání            </option>
# <option value="ORM">
# Orální podání            </option>
# <option value="ORM/POR">
# Orální/perorální podání            </option>
# <option value="ORP">
# Orofaryngeální podání            </option>
# <option value="PNR">
# Perineurální podání            </option>
# <option value="POR">
# Perorální podání            </option>
# <option value="POR/DRM">
# Perorální/kožní podání            </option>
# <option value="POR/GSR">
# Perorální/žaludeční podání            </option>
# <option value="POR/GST">
# Perorální/gastroenterální podání            </option>
# <option value="POR/INH">
# Perorální/inhalační podání            </option>
# <option value="POR/ORM/DRM">
# Perorální/orální/kožní podání            </option>
# <option value="POR/ORM/DRM/INH">
# Perorální/orální/kožní/inhalační podání            </option>
# <option value="POR/ORM/INH">
# Perorální/orální/inhalační podání            </option>
# <option value="POR/RCT">
# Perorální/rektální podání            </option>
# <option value="POR/VAG">
# Perorální/vaginální podání            </option>
# <option value="RCT">
# Rektální podání            </option>
# <option value="SBR">
# Subretinální podání            </option>
# <option value="SDR">
# Subkutánní podání            </option>
# <option value="SDR/IMS">
# Subkutánní/intramuskulární podání            </option>
# <option value="SDR/IMS/IVN">
# Subkutánní/intramuskulární/intravenózní podání            </option>
# <option value="SDR/IVN">
# Subkutánní/intravenózní podání            </option>
# <option value="SDR/IVN/EAC">
# Subkutánní/intravenózní/mimotělní podání            </option>
# <option value="SDR/IVN/HMD">
# Subkutánní/intravenózní podání/hemodialýza            </option>
# <option value="SDR/IVN/ITH">
# Subkutánní/intravenózní/intratekální podání            </option>
# <option value="SLG">
# Podání pod jazyk            </option>
# <option value="SLG/BUC">
# Podání pod jazyk/bukální podání            </option>
# <option value="TDR">
# Transdermální podání            </option>
# <option value="URT">
# Uretrální podání            </option>
# <option value="VAG">
# Vaginální podání            </option>
# <option value="VAG/DRM">
# Vaginální/kožní podání            </option>
# </select>
# <label for="data_reg">Stav registrace:</label>
# <select id="data_reg" name="data[reg]" size="1">
# <option value=""> - nerozhoduje - </option>
# <option title="registrovaný léčivý přípravek." value="R">
# R - registrovaný léčivý přípravek.
# </option>
# <option title="přípravek po provedené konverzi kódů. Smí být uváděn na trh po dobu 6 měsíců (Uvedení na trh do) a vydáván a používán do uplynutí doby použitelnosti." value="Q">
# Q - přípravek po provedené konverzi kódů. Smí být uváděn...
# </option>
# <option title="přípravek po provedené změně. Smí být uváděn na trh po dobu 6 měsíců od schválení změny (Uvedení na trh do) a vydáván a používán do uplynutí doby použitelnosti." value="B">
# B - přípravek po provedené změně. Smí být uváděn na trh...
# </option>
# <option title="zrušená registrace. Přípravek bude stažen z oběhu do doby uvedené v rozhodnutí o zrušení registrace (Platnost do)." value="C">
# C - zrušená registrace. Přípravek bude stažen z oběhu do...
# </option>
# <option title="specifický léčebný program povolený MZ ČR na základě doporučení SÚKL." value="F">
# F - specifický léčebný program povolený MZ ČR na základě...
# </option>
# <option title="potravina pro zvláštní lékařské účely." value="P">
# P - potravina pro zvláštní lékařské účely.
# </option>
# <option title="pozastavení registrace nebo používání léčivého přípravku a jeho uvádění do oběhu." value="M">
# M - pozastavení registrace nebo používání léčivého...
# </option>
# <option title="registrace, která pozbyla platnost. Přípravek bude stažen z oběhu do doby uvedené v rozhodnutí (Platnost do)." value="Y">
# Y - registrace, která pozbyla platnost. Přípravek bude...
# </option>
# </select>
# </div>
# <div class="column-wrapper">
# <div class="column wider">
# <input checked="checked" id="radio0" name="data[radio]" type="radio" value="none"/>
# <label for="radio0">Všechny léčivé přípravky</label><br/>
# <input id="radio1" name="data[radio]" type="radio" value="recipe"/>
# <label for="radio1">Léčivé přípravky vázané na lékařský předpis</label><br/>
# <input id="radio2" name="data[radio]" type="radio" value="blue-strip"/>
# <label for="radio2">Léčivé přípravky vázané na lékařský předpis s modrým pruhem</label><br/>
# <input id="radioL" name="data[radio]" type="radio" value="recipe-limited"/>
# <label for="radioL">Léčivé přípravky vázané na lékařský předpis s omezením</label><br/>
# <input id="radio3" name="data[radio]" type="radio" value="no-recipe"/>
# <label for="radio3">Léčivé přípravky bez lékařského předpisu</label><br/>
# <input id="radio4" name="data[radio]" type="radio" value="limited"/>
# <label for="radio4">Léčivé přípravky bez lékařského předpisu s omezením</label><br/>
# <input id="radio5" name="data[radio]" type="radio" value="limited_rlpo"/>
# <label for="radio5">Léčivé přípravky bez lékařského předpisu s omezením (RLPO)</label><br/>
# </div>
# <div class="column narrower">
# <input id="chbox07" name="data[chbox][]" title="Přípravky, které mají stanovenu úhradu z veřejného zdravotního pojištění, jsou barevně označeny." type="checkbox" value="funded"/> <label for="chbox07" title="Přípravky, které mají stanovenu úhradu z veřejného zdravotního pojištění, jsou barevně označeny.">
# Hrazené <sup style="font-size: xx-small">?</sup></label><br/>
# <input id="chbox08" name="data[chbox][]" title="Přípravky, u kterých úhrada ze zdravotního pojištění plně pokrývá orientační prodejní cenu." type="checkbox" value="fullpayed"/> <label for="chbox08" title="Přípravky, u kterých úhrada ze zdravotního pojištění plně pokrývá orientační prodejní cenu.">Plně hrazené <sup style="font-size: xx-small">?</sup></label><br/>
# <input id="chbox09" name="data[chbox][]" title="Obchodované - tučně jsou označeny přípravky s aktivním výskytem na českém trhu (dle pravidelného hlášení dodávek distributorů v předchozím čtvrtletí)." type="checkbox" value="marketability"/> <label for="chbox09" title="Obchodované - tučně jsou označeny přípravky s aktivním výskytem na českém trhu (dle pravidelného hlášení dodávek distributorů v předchozím čtvrtletí).">Obchodované <sup style="font-size: xx-small">?</sup></label><br/>
# <input id="chbox10" name="data[chbox][]" title="Nehrazené" type="checkbox" value="notfunded"/> <label for="chbox10" title="Nehrazené">
# Nehrazené <sup style="font-size: xx-small">?</sup></label><br/>
# </div>
# </div>
# <div class="block-hidden" id="med-extended-search">
# <div>
# <input id="chbox00" name="data[chbox][]" type="checkbox" value="program"/>
# <label for="chbox00">Léčivé přípravky ve specifickém léčebném programu</label><br/>
# <input id="chbox01" name="data[chbox][]" type="checkbox" value="reserved"/>
# <label for="chbox01">Vyhrazené léčivé přípravky</label><br/>
# <input id="chbox02" name="data[chbox][]" type="checkbox" value="homeopatics"/>
# <label for="chbox02">Homeopatika</label><br/>
# <input id="chbox03" name="data[chbox][]" type="checkbox" value="food"/>
# <label for="chbox03">Potraviny pro zvláštní lékařské účely (PZLÚ)</label><br/>
# <input id="chbox04" name="data[chbox][]" type="checkbox" value="import"/>
# <label for="chbox04">Léčivé přípravky v rámci souběžného dovozu a distribuce</label><br/>
# <input id="chbox05" name="data[chbox][]" type="checkbox" value="charges"/>
# <label for="chbox05">Léčivé přípravky s povolenou cizojazyčnou šarží</label><br/>
# <input id="chbox06" name="data[chbox][]" type="checkbox" value="doping"/>
# <label for="chbox06">Léčivé přípravky s podezřením na doping</label><br/>
# </div>
# <div class="block-texts">
# <label for="data_rc">Registrační číslo:</label>
# <input id="data_rc" name="data[rc]" type="text" value=""/>
# </div>
# <div>
# <b>Braillovo písmo:</b><br/>
# <input checked="checked" id="braill1" name="data[chbox][]" type="checkbox" value="braill-yes"/>
# <label for="braill1">Schváleno – text na obalu odpovídá zákonným požadavkům.</label><br/>
# <input checked="checked" id="braill2" name="data[chbox][]" type="checkbox" value="braill-no"/>
# <label for="braill2">Výjimka.</label><br/>
# <input checked="checked" id="braill3" name="data[chbox][]" type="checkbox" value="braill-def"/>
# <label for="braill3">U léčivého přípravku nebylo požádáno o uvedení Braillova písma na obalu, resp. o výjimku z uvedení Braillova písma na obalu, nebo tato žádost nebyla vyřízena.</label><br/>
# </div>
# <div style="clear: both"></div>
# <div style="overflow: auto; padding-top: 20px;">
# <div style="float: left; width: 280px;">
# Držitel rozhodnutí o registraci:
# </div>
# <div style="background: white; border: 1px gray inset; float: left; height: 150px; overflow: auto; width: 373px;">
# <div style="white-space: nowrap;">
# <input id="PGZ-A" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="PGZ-A"/>
# <label for="PGZ-A" style="display: inline !important; float: none! important;">
# +pharma arzneimittel gmbh, Graz, RAKOUSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="XAP-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="XAP-D"/>
# <label for="XAP-D" style="display: inline !important; float: none! important;">
# 1 A Pharma GmbH, Oberhaching, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="MEN-I" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="MEN-I"/>
# <label for="MEN-I" style="display: inline !important; float: none! important;">
# A. Menarini Industrie Farmaceutiche Riunite S.r.l., Florencie, ITÁLIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACM-I" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACM-I"/>
# <label for="ACM-I" style="display: inline !important; float: none! important;">
# A.C.O.M. -ADVANCED CENTER ONCOLOGY MACERATA -S.R.L., Montecosaro, ITÁLIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="BWL-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="BWL-D"/>
# <label for="BWL-D" style="display: inline !important; float: none! important;">
# AbbVie Deutschland GmbH &amp; Co.KG, Ludwigshafen, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ABV-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ABV-CZ"/>
# <label for="ABV-CZ" style="display: inline !important; float: none! important;">
# AbbVie s.r.o., Praha, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AED-P" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AED-P"/>
# <label for="AED-P" style="display: inline !important; float: none! important;">
# Abdi Farma, Unipessoal Lda., Paco de Arcos, PORTUGALSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ANV-B" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ANV-B"/>
# <label for="ANV-B" style="display: inline !important; float: none! important;">
# Ablynx NV, Zwijnaarde, BELGIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AHN-GB" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AHN-GB"/>
# <label for="AHN-GB" style="display: inline !important; float: none! important;">
# Accord Healthcare Limited, North Harrow, VELKÁ BRITÁNIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AHP-PL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AHP-PL"/>
# <label for="AHP-PL" style="display: inline !important; float: none! important;">
# ACCORD HEALTHCARE POLSKA Sp. z o.o., Varšava, POLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACH-E" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACH-E"/>
# <label for="ACH-E" style="display: inline !important; float: none! important;">
# Accord Healthcare S.L.U., Barcelona, ŠPANĚLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACC-PL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACC-PL"/>
# <label for="ACC-PL" style="display: inline !important; float: none! important;">
# Accupharma Sp. z o.o., Varšava, POLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACR-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACR-IRL"/>
# <label for="ACR-IRL" style="display: inline !important; float: none! important;">
# Acorda Therapeutics Ireland, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ATV-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ATV-CZ"/>
# <label for="ATV-CZ" style="display: inline !important; float: none! important;">
# Actavis CZ a.s., v likvidaci, Praha, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACV-IS" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACV-IS"/>
# <label for="ACV-IS" style="display: inline !important; float: none! important;">
# Actavis Group Hf., Hafnarfjördur, ISLAND
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AGJ-IS" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AGJ-IS"/>
# <label for="AGJ-IS" style="display: inline !important; float: none! important;">
# Actavis Group Ltd., Hafnarfjördur, ISLAND
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACK-IS" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACK-IS"/>
# <label for="ACK-IS" style="display: inline !important; float: none! important;">
# Actavis Group PTC ehf., Hafnarfjördur, ISLAND
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ANF-DK" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ANF-DK"/>
# <label for="ANF-DK" style="display: inline !important; float: none! important;">
# Actavis Nordic A/S, Gentofte, DÁNSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACB-GB" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACB-GB"/>
# <label for="ACB-GB" style="display: inline !important; float: none! important;">
# Actelion Registration Ltd., London, VELKÁ BRITÁNIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AKN-CY" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AKN-CY"/>
# <label for="AKN-CY" style="display: inline !important; float: none! important;">
# Activase Pharmaceuticals Ltd., Nicosia, KYPR
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADD-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADD-CZ"/>
# <label for="ADD-CZ" style="display: inline !important; float: none! important;">
# Adamed Czech Republic, s. r. o., Praha, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADP-PL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADP-PL"/>
# <label for="ADP-PL" style="display: inline !important; float: none! important;">
# Adamed Pharma S.A., Czosnów, POLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADD-PL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADD-PL"/>
# <label for="ADD-PL" style="display: inline !important; float: none! important;">
# Adamed Sp. z o.o., Czosnów, POLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADA-I" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADA-I"/>
# <label for="ADA-I" style="display: inline !important; float: none! important;">
# Addenda Pharma S.r.l., Bologna, ITÁLIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADC-F" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADC-F"/>
# <label for="ADC-F" style="display: inline !important; float: none! important;">
# Addmedica, Paříž, FRANCIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AJB-I" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AJB-I"/>
# <label for="AJB-I" style="display: inline !important; float: none! important;">
# ADIENNE S.r.l., Caponago, ITÁLIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AFU-A" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AFU-A"/>
# <label for="AFU-A" style="display: inline !important; float: none! important;">
# Adler Pharma Produktion und Vertrieb GmbH, Zell am See, RAKOUSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADN-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADN-D"/>
# <label for="ADN-D" style="display: inline !important; float: none! important;">
# Admeda Arzneimittel GmbH, Nienwohld, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AKS-F" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AKS-F"/>
# <label for="AKS-F" style="display: inline !important; float: none! important;">
# Advanced Accelerator Applications, Saint Genis Pouilly, FRANCIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AFI-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AFI-IRL"/>
# <label for="AFI-IRL" style="display: inline !important; float: none! important;">
# Aerie Pharmaceuticals Ireland, Limited, Athlone, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AET-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AET-D"/>
# <label for="AET-D" style="display: inline !important; float: none! important;">
# Aeterna Zentaris GmbH, Frankfurt, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AFO-PL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AFO-PL"/>
# <label for="AFO-PL" style="display: inline !important; float: none! important;">
# Aflofarm Farmacja Polska Sp. z o.o., Pabianice, POLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AGA-S" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AGA-S"/>
# <label for="AGA-S" style="display: inline !important; float: none! important;">
# AGA AB, LIDINGÖ, ŠVÉDSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AGH-SK" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AGH-SK"/>
# <label for="AGH-SK" style="display: inline !important; float: none! important;">
# AGEPHA PHARMA s.r.o., Senec, SLOVENSKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AIP-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AIP-CZ"/>
# <label for="AIP-CZ" style="display: inline !important; float: none! important;">
# Air Products spol. s r.o., Děčín, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AID-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AID-CZ"/>
# <label for="AID-CZ" style="display: inline !important; float: none! important;">
# AIR Products spol. s r.o., Děčín, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AKA-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AKA-CZ"/>
# <label for="AKA-CZ" style="display: inline !important; float: none! important;">
# Akacia Group s.r.o., Praha, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AKH-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AKH-CZ"/>
# <label for="AKH-CZ" style="display: inline !important; float: none! important;">
# Akademie klasické homeopatie, spol. s r.o., Ostrava, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AKD-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AKD-CZ"/>
# <label for="AKD-CZ" style="display: inline !important; float: none! important;">
# Akademie klasické homeopatie, spol. s r.o., Ostrava, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AKI-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AKI-IRL"/>
# <label for="AKI-IRL" style="display: inline !important; float: none! important;">
# Akcea Therapeutics Ireland Ltd, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACI-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACI-CZ"/>
# <label for="ACI-CZ" style="display: inline !important; float: none! important;">
# Alcon Pharmaceuticals  (Czech Republic) s.r.o., Praha, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACU-B" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACU-B"/>
# <label for="ACU-B" style="display: inline !important; float: none! important;">
# Alcon-Couvreur N.V., Puurs, BELGIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALE-F" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALE-F"/>
# <label for="ALE-F" style="display: inline !important; float: none! important;">
# Alexion Europe SAS, Levallois-Perret, FRANCIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AEN-F" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AEN-F"/>
# <label for="AEN-F" style="display: inline !important; float: none! important;">
# Alexion Europe SAS, Rueil-Malmaison, FRANCIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ASW-I" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ASW-I"/>
# <label for="ASW-I" style="display: inline !important; float: none! important;">
# Alfa Wassermann S.p.A., Alanno, ITÁLIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ASF-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ASF-CZ"/>
# <label for="ASF-CZ" style="display: inline !important; float: none! important;">
# ALFASIGMA CZECH s.r.o., Praha, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALA-I" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALA-I"/>
# <label for="ALA-I" style="display: inline !important; float: none! important;">
# Alfasigma S.p.A., Bologna, ITÁLIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="TIE-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="TIE-D"/>
# <label for="TIE-D" style="display: inline !important; float: none! important;">
# Alfred E. Tiefenbacher GmbH &amp; Co. KG, Hamburg, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ASL-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ASL-IRL"/>
# <label for="ASL-IRL" style="display: inline !important; float: none! important;">
# ALIMERA SCIENCES EUROPE LIMITED, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ARS-GB" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ARS-GB"/>
# <label for="ARS-GB" style="display: inline !important; float: none! important;">
# Alimera Sciences Limited, Aldershot, VELKÁ BRITÁNIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AYL-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AYL-D"/>
# <label for="AYL-D" style="display: inline !important; float: none! important;">
# Aliud Pharma GmbH, Laichingen, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALH-DK" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALH-DK"/>
# <label for="ALH-DK" style="display: inline !important; float: none! important;">
# ALK-Abelló A/S, Horsholm, DÁNSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AIJ-SLO" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AIJ-SLO"/>
# <label for="AIJ-SLO" style="display: inline !important; float: none! important;">
# Alkaloid - INT d.o.o., Ljubljana - Črnuče, SLOVINSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALB-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALB-IRL"/>
# <label for="ALB-IRL" style="display: inline !important; float: none! important;">
# Allergan Pharmaceuticals International Limited, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="API-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="API-IRL"/>
# <label for="API-IRL" style="display: inline !important; float: none! important;">
# Allergan Pharmaceuticals International Limited, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALL-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALL-IRL"/>
# <label for="ALL-IRL" style="display: inline !important; float: none! important;">
# Allergan Pharmaceuticals Ireland, Westport, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ATG-GB" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ATG-GB"/>
# <label for="ATG-GB" style="display: inline !important; float: none! important;">
# Allergy Therapeutics (UK) Limited, Worthing, VELKÁ BRITÁNIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ATI-E" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ATI-E"/>
# <label for="ATI-E" style="display: inline !important; float: none! important;">
# ALLERGY THERAPEUTICS IBERICA, SL, Barcelona, ŠPANĚLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AHR-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AHR-D"/>
# <label for="AHR-D" style="display: inline !important; float: none! important;">
# Almirall Hermal GmbH, Reinbek, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="LTB-E" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="LTB-E"/>
# <label for="LTB-E" style="display: inline !important; float: none! important;">
# Almirall, S.A., Barcelona, ŠPANĚLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALM-NL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALM-NL"/>
# <label for="ALM-NL" style="display: inline !important; float: none! important;">
# Alnylam Netherlands B.V., Amsterdam, NIZOZEMSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALX-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALX-IRL"/>
# <label for="ALX-IRL" style="display: inline !important; float: none! important;">
# Alpex Pharma (IRL) Limited, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALX-GB" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALX-GB"/>
# <label for="ALX-GB" style="display: inline !important; float: none! important;">
# Alpex Pharma (UK) Limited, Bedford, VELKÁ BRITÁNIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AXV-L" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AXV-L"/>
# <label for="AXV-L" style="display: inline !important; float: none! important;">
# Alvogen IPCo S.ar.l., Senningerberg, LUCEMBURSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AXV-M" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AXV-M"/>
# <label for="AXV-M" style="display: inline !important; float: none! important;">
# Alvogen Malta Operations ROW Ltd., San Gwann, MALTA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ALV-BG" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ALV-BG"/>
# <label for="ALV-BG" style="display: inline !important; float: none! important;">
# Alvogen Pharma Trading Europe EOOD, Sofia, BULHARSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ADB-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ADB-IRL"/>
# <label for="ADB-IRL" style="display: inline !important; float: none! important;">
# Amdipharm Limited, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AEB-NL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AEB-NL"/>
# <label for="AEB-NL" style="display: inline !important; float: none! important;">
# Amgen Europe B.V., Breda, NIZOZEMSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ATQ-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ATQ-IRL"/>
# <label for="ATQ-IRL" style="display: inline !important; float: none! important;">
# Amgen Technology (Ireland) Unlimited Company, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AMS-H" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AMS-H"/>
# <label for="AMS-H" style="display: inline !important; float: none! important;">
# Amicus Pharma Kft., Budapešť, MAĎARSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AMI-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AMI-IRL"/>
# <label for="AMI-IRL" style="display: inline !important; float: none! important;">
# Amicus Therapeutics Europe Limited, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AMK-F" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AMK-F"/>
# <label for="AMK-F" style="display: inline !important; float: none! important;">
# AMMTeK, Paris, FRANCIE
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AMO-A" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AMO-A"/>
# <label for="AMO-A" style="display: inline !important; float: none! important;">
# Amomed Pharma GmbH, Vídeň, RAKOUSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ACS-R" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ACS-R"/>
# <label for="ACS-R" style="display: inline !important; float: none! important;">
# AMRING FARMA SRL, Bucharest, RUMUNSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ATA-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ATA-D"/>
# <label for="ATA-D" style="display: inline !important; float: none! important;">
# Amryt AG, Niefern-Öschelbronn, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ART-IRL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ART-IRL"/>
# <label for="ART-IRL" style="display: inline !important; float: none! important;">
# Amryt Pharmaceuticals DAC, Dublin, IRSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ANG-E" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ANG-E"/>
# <label for="ANG-E" style="display: inline !important; float: none! important;">
# Angelini Farmaceutica S.A., Barcelona, ŠPANĚLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="ANG-CZ" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="ANG-CZ"/>
# <label for="ANG-CZ" style="display: inline !important; float: none! important;">
# Angelini Pharma Česká republika s.r.o., Brno, ČESKÁ REPUBLIKA
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="APO-A" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="APO-A"/>
# <label for="APO-A" style="display: inline !important; float: none! important;">
# Angelini Pharma Österreich GmbH, Vídeň, RAKOUSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AFW-PL" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AFW-PL"/>
# <label for="AFW-PL" style="display: inline !important; float: none! important;">
# ANPHARM Przedsiebiorstwo Farmaceutyczne S.A., Warszawa, POLSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AOH-A" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AOH-A"/>
# <label for="AOH-A" style="display: inline !important; float: none! important;">
# AOP Orphan Pharmaceuticals AG, Wien, RAKOUSKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="APG-D" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="APG-D"/>
# <label for="APG-D" style="display: inline !important; float: none! important;">
# Apogepha Arzneimittel GmbH, Drážďany, NĚMECKO
# </label><br/>
# </div><div style="white-space: nowrap;">
# <input id="AXF-A" name="data[drz][]" style="width: 16px !important;" type="checkbox" value="AXF-A"/>
# <label for="AXF-A" style="display: inline !important; float: none! important;">
# ...
# <br/>
# Přípravky s aktivním výskytem na českém trhu dle pravidelného hlášení dodávek distributorů v období předchozích tří měsíců (s měsíčním odstupem) jsou označeny symbolem <img src="http://www.sukl.cz/themes/sukl2//images/check.png"/> a jsou uvedeny tučně.
# </p>
# </fieldset>
# <div class="medication center small">
# Aktualizace registračních údajů:
# 19. listopad 2020 v 00:08
# <br/>
# Aktualizace cenových a úhradových údajů:
# 31. říjen 2020 v 00:09
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="right">
# <div class="column-in">
# </div>
# </div>
# </div>
# <h2 class="hidden">Navigace</h2>
# <div class="left">
# <div class="column-in">
# <div id="menu">
# </div>
# <div id="ebanner">
# <div class="bl" id="b-43">
# <div class="article-content">
# <p>
# <a href="http://www.epreskripce.cz"><img alt="erecept_logo_barevne_1.jpg" border="border" class="null" height="234" hspace="" src="/uploads/image/erecept_logo_barevne_1.jpg" width="387"/></a>
# </p>
# </div>
# </div>
# <div class="bl" id="b-48">
# <div class="article-content">
# <p>
# <a class="new-window" href="http://www.lekovyzaznam.cz" onclick="return !bar(this.href);" title="[Odkaz do nového okna] "><img alt="slz.PNG" border="border" class="null" height="44" hspace="" src="/uploads/slz.PNG" width="262"/></a>
# </p>
# </div>
# </div>
# <div class="bl" id="b-50">
# <div class="article-content">
# <p>
# <a href="/covid-19"><img alt="covid.PNG" border="border" height="43" hspace="" src="/uploads/covid.PNG" width="261"/></a>
# </p>
# </div>
# </div>
# </div>
# <div id="left_shortcuts">
# <div class="bl" id="b-40">
# <span class="left_menu_top"></span> <ul class="level1">
# <li class="first active">
# <a class="databaze-registrovanych-leciv" href="/modules/medication/search.php" title="Databáze léků">Databáze léků</a>
# </li>
# <li class="e">
# <a class="databaze-lekaren" href="/modules/apotheke/search.php" title="Databáze lékáren">Databáze lékáren</a>
# </li>
# <li class="o">
# <a class="prehled-povolenych-klinickych-hodnoceni" href="/modules/evaluation/" title="Databáze klinic. hodnocení">Databáze klinic. hodnocení</a>
# </li>
# <li class="e">
# <a class="registr-zdravotnickych-prostredku" href="http://www.rzpro.cz/" title="Registr zdrav. prostředků">Registr zdrav. prostředků</a>
# </li>
# <li class="o">
# <a class="konopi-k-lecebnym-ucelum" href="http://www.sukl.cz/konopi-k-lecebnym-ucelum" title="Konopí k léčebným účelům">Konopí k léčebným účelům</a>
# </li>
# <li class="e">
# <a class="dulezite-informace-a-upozorneni-sukl" href="http://www.sukl.cz/dulezite-informace-a-upozorneni-sukl" title="Důležitá upozornění">Důležitá upozornění</a>
# </li>
# <li class="o">
# <a class="hlaseni-pro-sukl" href="http://www.sukl.cz/hlaseni-pro-sukl" title="Hlášení pro SÚKL">Hlášení pro SÚKL</a>
# </li>
# <li class="e">
# <a class="informace-k-brexitu" href="http://www.sukl.cz/farmaceuticky-prumysl/brexit" title="Informace k Brexitu">Informace k Brexitu</a>
# </li>
# <li class="o">
# <a class="informace-k-ochrannym-prvkum" href="http://www.sukl.cz/ochranne-prvky" title="Ochranné prvky">Ochranné prvky</a>
# </li>
# <li class="e">
# <a class="dodavky-a-jina-hodnoceni" href="http://www.sukl.cz/dodavky-a-jina-hodnoceni" title="Dodávky a jiná hodnocení">Dodávky a jiná hodnocení</a>
# </li>
# <li class="o">
# <a class="prehledy-a-databaze-sukl" href="http://www.sukl.cz/prehledy-a-databaze-sukl" title="Přehledy a seznamy">Přehledy a seznamy</a>
# </li>
# <li class="e">
# <a class="otevrena-data" href="https://opendata.sukl.cz/" title="Otevřená data">Otevřená data</a>
# </li>
# <li class="o">
# <a class="vypadky-leku" href="http://www.sukl.cz/vypadky-leku" title="Výpadky léků">Výpadky léků</a>
# </li>
# </ul>
# </div>
# </div>
# <div id="left_publications">
# <div class="bl" id="b-45">
# <div class="article-content">
# <p>
# <strong>  </strong> <a href="/ochrana-osobnich-udaju"><strong>OCHRANA OSOBNÍCH ÚDAJŮ</strong></a>
# </p>
# </div>
# </div>
# <div class="bl" id="b-44">
# <div class="article-content">
# <p>
# <a href="https://www.niszp.cz/"><img alt="NISZP.JPG" border="border" height="32" hspace="" src="/uploads/NISZP.JPG" width="212"/></a>
# </p>
# </div>
# </div>
# </div>
# <div id="left_map">
# </div>
# </div>
# </div>
# <div class="cleaner"> </div>
# </div>
# <h2 class="hidden">Vyhledávání</h2>
# <div id="search_fulltext">
# <form action="http://www.sukl.cz/search.php" id="searchform">
# <div>
# <input name="action" type="hidden" value="results"/>
# <label><input accesskey="4" id="search-input" name="query" onblur="searchRestore(this, '');" onfocus="searchClear(this,  '');" value=""/></label>
# <label><input alt="VYHLEDÁVÁNÍ" id="go_button" src="http://www.sukl.cz/themes/sukl2/images/search-btn.png" type="image"/></label>
# </div>
# </form> </div>
# <div id="user_info">
# </div>
# <div id="telephone-list">
# <div class="bl" id="b-32">
# <div class="article-content">
# <p>
# <a href="/sukl/kontakty-na-utvary-sukl">+420 272 185 111<br/>
# <span>Kontakty na útvary SÚKL</span></a>
# </p>
# </div>
# </div>
# </div>
# <div id="lang-block">
# <div class="bl" id="b-22">
# <div style="text-align: center">
# <a href="http://www.sukl.cz/modules/medication/search.php?data%5Bsearch_for%5D=&amp;data%5Bcode%5D=&amp;data%5Batc_group%5D=&amp;data%5Bmaterial%5D=&amp;data%5Bpath%5D=&amp;data%5Breg%5D=&amp;data%5Bradio%5D=none&amp;data%5Brc%5D=&amp;data%5Bchbox%5D%5B0%5D=braill-yes&amp;data%5Bchbox%5D%5B1%5D=braill-no&amp;data%5Bchbox%5D%5B2%5D=braill-def&amp;data%5Bwith_adv%5D=0&amp;data%5Blisting%5D=100&amp;search=Vyhledat&amp;lang=1">
# <img alt="cs_CZ" src="http://www.sukl.cz/modules/language/images/flags/czech.gif"/>
# </a>
# <a href="http://www.sukl.eu/modules/medication/search.php?data%5Bsearch_for%5D=&amp;data%5Bcode%5D=&amp;data%5Batc_group%5D=&amp;data%5Bmaterial%5D=&amp;data%5Bpath%5D=&amp;data%5Breg%5D=&amp;data%5Bradio%5D=none&amp;data%5Brc%5D=&amp;data%5Bchbox%5D%5B0%5D=braill-yes&amp;data%5Bchbox%5D%5B1%5D=braill-no&amp;data%5Bchbox%5D%5B2%5D=braill-def&amp;data%5Bwith_adv%5D=0&amp;data%5Blisting%5D=100&amp;search=Vyhledat&amp;lang=2">
# <img alt="en_GB" src="http://www.sukl.cz/modules/language/images/flags/english.gif"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="portal_ads_w">
# <div id="portal_ads_temp">
# <div id="portal_ads">
# <div class="bl" id="b-38">
# <h2>Navštivte také naše další stránky</h2>
# <div class="article-content">
# <div class="next_portal">
# <a class="img leky_sukl" href="http://www.olecich.cz" title="Informační portál pro veřejnost">www.olecich.cz</a>
# <p>
# <a href="http://www.olecich.cz" title="Informační portál pro veřejnost">Informační portál<br/>
# pro veřejnost</a>
# </p>
# </div>
# <div class="next_portal">
# <a class="img nebezpecne_leky" href="http://www.nebezpecneleky.cz" title="Mohou nelegální léky poškodit Vaše zdraví?">nebezpecneleky.cz</a>
# <p>
# <a href="http://www.nebezpecneleky.cz" title="Mohou nelegální léky poškodit Vaše zdraví?">Mohou nelegální léky<br/>
# poškodit Vaše zdraví?</a>
# </p>
# </div>
# <div class="next_portal">
# <a class="img identity_salk" style="display: none;" title="Státní agentura pro léčebné konopí">SALK</a>
# <p style="display: none;">
# <span title="Státní agentura pro léčebné konopí">Státní agentura<br/>
# pro léčebné konopí</span>
# </p>
# </div>
# <div class="next_portal">
# <a class="img erecept" href="https://www.epreskripce.cz/" title="Informace k elektronickému receptu">eRecept</a>
# <p>
# <a href="https://www.epreskripce.cz/" title="Informace k elektronickému receptu">Informace k elektronickému<br/>
# receptu</a>
# </p>
# </div>
# <div class="next_portal last">
# <a class="img lekarny_sukl" href="https://pristupy.sukl.cz" title="Zajištění přístupů k IT systémům SÚKL">pristupy.sukl.cz</a>
# <p>
# <a href="https://pristupy.sukl.cz" title="Zajištění přístupů k IT systémům SÚKL">Zajištění přístupů k IT systémům SÚKL<br/></a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cleaner"></div>
# </div>
# <div id="footer_w">
# <div id="footer">
# <div class="column-in">
# <div class="bl" id="b-37">
# <div class="article-content">
# <div class="next_portal">
# <h3>
# <a href="/sukl/ostatni-cinnosti">Ostatní činnosti</a>
# </h3>
# <ul>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/legislativa-a-pokyny" title="Legislativa a pokyny">Legislativa a pokyny</a></span></strong>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/konzultace-sukl" title="Konzultace SÚKL">Konzultace SÚKL</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/administracni-cinnost" title="Administrační činnost">Administrační činnost</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/publikacni-cinnost" title="Publikační činnost">Publikační činnost</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/mezinarodni-aktivity" title="Mezinárodní aktivity">Mezinárodní aktivity</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/externi-spoluprace" title="Externí spolupráce">Externí spolupráce</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/vzory-plne-moci" title="Plné moci - informace">Plné moci</a></span>
# </li>
# </ul>
# </div>
# <div class="next_portal">
# <h3>
# <a href="/sukl/uredni-deska">Úřední deska SÚKL</a>
# </h3>
# <ul>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/dorucovani-verejnou-vyhlaskou" title="Doručování veřejnou vyhláškou">Doručování veřejnou vyhláškou</a></span></strong>
# </li>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/modules/delivery/?a=devicesRegistration" title="Ohlášení úhrad ZP">Ohlášení úhrad ZP</a></span></strong>
# </li>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/informace-o-prubehu-spravnich-rizeni" title="Informace o průběhu správních řízení">Informace o průběhu správních řízení</a></span></strong>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/opatreni-obecne-povahy" title="Opatření obecné povahy">Opatření obecné povahy</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/vyzva-sukl-k-prevzeti-registrace" title="Výzvy SÚKL">Výzvy SÚKL</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/navrhy-dokumentu-sukl-k-pripominkovani" title="Návrhy dokumentů SÚKL k připomínkování">Návrhy dokumentů SÚKL k připomínkování</a></span>
# </li>
# </ul><a class="iconic" href="/sukl/uredni-deska">zobrazit celou sekci</a>
# </div>
# <div class="next_portal">
# <h3>
# <a href="/sukl/sazebnik-a-poplatky">Sazebník a poplatky</a>
# </h3>
# <ul>
# <li>
# <strong><span class="mw_field"><a href="/modules/payment/" title="Formulář pro platbu náhrad výdajů a správních poplatků">Formulář pro platbu náhrad výdajů ...</a></span></strong>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/pokyny-k-platbe-nahrad-vydaju-a-spravnich-poplatku" title="Pokyny k úhradám poplatků">Pokyny k úhradám poplatků</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/uhrada-nahrad-vydaju-za-odborne-ukony-provadene-na-zadost" title="Úhrada náhrad výdajů za odborné úkony prováděné na žádost">Úhrada náhrad výdajů za odborné úkony ...</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/uhrada-spravnich-poplatku" title="Úhrada správních poplatků">Úhrada správních poplatků</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/bankovni-spojeni" title="Bankovní spojení">Bankovní spojení</a></span>
# </li>
# </ul><a class="iconic" href="/sukl/sazebnik-a-poplatky">zobrazit celou sekci</a>
# </div>
# <div class="next_portal">
# <h3>
# <a href="/sukl/dalsi-informace?lang=1">Další informace</a>
# </h3>
# <ul>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/povereni-inspektori" title="Pověření inspektoři">Pověření inspektoři</a></span>
# </li>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/verejne-zakazky" title="Veřejné zakázky">Veřejné zakázky</a></span></strong>
# </li>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/vzdelavaci-akce" title="Vzdělávací akce">Vzdělávací akce</a></span></strong>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/kariera" title="Kariéra">Kariéra</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/eticke-komise" title="Etické komise">Etické komise</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/krajske-urady" title="Krajské úřady">Krajské úřady</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/nabidky-nepotrebneho-majetku" title="Nabídky nepotřebného majetku">Nabídky nepotřebného majetku</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/dalsi-informace/rozpocet-statniho-ustavu-pro-kontrolu-leciv" title="Rozpočet Státního ústavu pro kontrolu léčiv">Rozpočet Státního ústavu pro kontrolu léčiv</a></span>
# </li>
# </ul>
# </div>
# <div class="next_portal last">
# <h3>
# <a href="/sukl/kontakty-mapy-spojeni">Kontakty</a>
# </h3>
# <ul>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/kontakty-na-utvary-sukl" title="Telefonní seznam">Kontakty na útvary SÚKL</a></span></strong>
# </li>
# <li>
# <strong><span class="mw_field"><a href="http://www.sukl.cz/sukl/regionalni-pracoviste-sukl" title="Regionální pracoviště SÚKL">Regionální pracoviště SÚKL</a></span></strong>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/centralni-kontakty" title="Centrální kontakty">Centrální kontakty</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/podatelna-pokladna" title="Podatelna - pokladna">Podatelna - pokladna</a></span>
# </li>
# <li>
# <span class="mw_field"><a href="http://www.sukl.cz/sukl/elektronicka-podatelna-1" title="Elektronická podatelna">Elektronická podatelna</a></span>
# </li>
# <li>
# <span class="mw_field"></span>
# </li>
# </ul><a class="iconic" href="/sukl/kontakty-mapy-spojeni">zobrazit celou sekci</a>
# </div>
# </div>
# </div>
# <div class="cleaner"></div>
# <div class="ft_link_up_line">
# <div class="lgn">
# <a href="/user.php">Přihlášení</a> <div id="suklIntranetLinkContainer"></div>
# </div>
# <div class="bl" id="b-18">
# <div class="article-content">
# <div class="along">
# <p>
# <a class="archiv" href="/archiv">Archiv</a>
# |
# <a class="webmaster" href="mailto: webmaster@sukl.cz">Webmaster</a>
# |
# <a class="prohlaseni-o-pristupnosti" href="http://www.sukl.cz/prohlaseni-o-pristupnosti">Prohlášení o přístupnosti</a>
# |
# <a class="podminky-vyuzivani-sluzeb-webove-prezentace" href="http://www.sukl.cz/podminky-vyuzivani-sluzeb-webove-prezentace">Podmínky využívání služeb webové prezentace</a>
# |
# <a class="zasady-ochrany-soukromi-navstevniku-stranek" href="http://www.sukl.cz/zasady-ochrany-soukromi-navstevniku-stranek">Zásady ochrany soukromí návštěvníků stránek</a>
# |
# <a class="povinne-informace" href="/povinne-informace">Povinné informace</a>
# |
# <a class="kontakty-1-1" href="/sukl/kontakty-na-utvary-sukl">Kontakty na útvary SÚKL</a>
# |
# <a class="mapa-stranek" href="http://www.sukl.cz/mapa-stranek">Mapa stránek</a>
# |
# <a class="novinky-e-mailem" href="http://www.sukl.cz/novinky-e-mailem">Novinky e-mailem</a>
# |
# <a class="rss" href="http://www.sukl.cz/rss">RSS</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="copyright">
# <div class="sukl-info">
# <div class="bl" id="b-34">
# <div class="article-content">
# <p class="pul-doleva" style="width: 540px; margin-top: 5px;">
# <img alt="oplzz.jpg" height="55" src="/uploads/oplzz.jpg" width="506"/>
# </p>
# <p class="pul-doleva" style="width: 180px; margin-top: 5px;">
# <img alt="dobry andele" src="/uploads/logoandelw.jpg" width="130"/>
# </p>
# <p class="pul-doprava" style="width: 260px; margin-top: 5px;">
# 2010 © SÚKL. Šrobárova 48,<br/>
# 100 41 Praha 10,<br/>
# +420 272 185 111<br/>
# <span class="eaddress">posta@sukl<img alt="_" src="/modules/marwel/images/tecka.gif"/>cz</span>.
# </p>
# </div>
# </div>
# </div>
# <div class="qcm-info">
# <p><a href="http://www.qcm.cz" title="Dodavatel webových portálů a internetových řešení">Dodavatel portálového řešení QCM, s.r.o.<span> </span></a></p>
# </div>
# </div>
# </body>
# </html>
# <!-- qcmmon state ok -->>
